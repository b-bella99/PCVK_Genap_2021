# %% [markdown]
# <a href="https://colab.research.google.com/github/b-bella99/PCVK_Genap_2021/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. meng-import folder yangada di Drive dengan cara berikut:

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang sudah ada. Contohnya pada kode program di bawah file image dengan nama kucing.jpg akan dibuka untuk diproses lebih lanjut

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/kucingKecil.jpg')
plt.imshow(img)       # perhatikan hasilnya adalah citra dgn channel  warna BGR

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red) Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

# Simpan file image
#cv.imwriter('/content/drive/MyDrive/kucing.jpg',img5)

#tampilkan plot dengan ukuran convas yang lebih besar
fig = plt.figure(figsize=(10,10))     # Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) # Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Tugas**

# %%
img6 = img

#tampilkan plot dengan ukuran convas yang lebih besar
fig = plt.figure(figsize=(5,5))     # Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img6)

# %% [markdown]
# 2.	Tampilkan image dalam channel Red-Green dan Green-Blue saja

# %%
img8 = cv.imread('/content/drive/MyDrive/kucingKecil.jpg')
img9 = cv.cvtColor(img8,cv.COLOR_BGR2RGB) #to RGB
rg = img9.copy() # make a copy
rg[:,:,2] = 0
plt.imshow(rg)

# %%
gb = img9.copy() # make a copy
gb[:,:,0] = 0
plt.imshow(gb)

# %% [markdown]
# 3. Tampilkan image baris ke 10-100, kolom 10-100

# %%
img10 = img9
imgbk = img10[10:100,10:100]
plt.imshow(imgbk)

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
img11 = img9.copy()
img11[:,:,0] = 0
img11[:,:,2] = 0
img25 = img11[5:30]
plt.imshow(img25)

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.disarankan menggunakan bilangan acak/random!

# %%
square = img9
cv.rectangle(square, pt1=(128,20), pt2=(133,50),color=(255,0,0),thickness=2)
cv.rectangle(square, pt1=(270,110), pt2=(300,140),color=(0,255,0),thickness=3)
cv.rectangle(square, pt1=(325,210), pt2=(370,240),color=(0,0,255),thickness=4)
cv.rectangle(square, pt1=(447,333), pt2=(489,389),color=(255,255,0),thickness=5)
cv.rectangle(square, pt1=(568,442), pt2=(590,489),color=(255,0,255),thickness=6)
plt.imshow(square)

# %% [markdown]
# 6. 6.	Tampilkan image dengan posisi terbalik

# %%
imgflip = cv.flip(cv.cvtColor(img8,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(imgflip)

# %% [markdown]
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas

# %%
wirakarya = cv.imread('/content/drive/MyDrive/wirakarya_kampung_kelir.jpg')
img10 = cv.cvtColor(wirakarya,cv.COLOR_BGR2RGB)

cv.rectangle(img10, pt1=(200,100), pt2=(140,160),color=(255,0,0),thickness=2)
cv.circle(img10, center=(170,130), radius=30,color=(0,0,255),thickness=2)

plt.imshow(img10)

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
sailboat = cv.imread('/content/drive/MyDrive/sailboat.jpg')
sailboat = cv.cvtColor(sailboat,cv.COLOR_BGR2RGB)

plt.imshow(sailboat)

# %%
cv.rectangle(sailboat, pt1=(200,800),pt2=(10,1000),color=(255,255,255),thickness=2)
plt.imshow(sailboat)

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda

# %%
font = cv.FONT_HERSHEY_TRIPLEX
cv.putText(sailboat,text='Sailboat',org=(100,650),fontFace=font,fontScale=4,color=(0,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(sailboat)
